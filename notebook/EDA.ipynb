# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from geopy.distance import great_circle
from geographiclib.geodesic import Geodesic

# %% [markdown]
# ## Reading Data

# %%
train = pd.read_csv("../data/train.csv")
val = pd.read_csv("../data/val.csv")

# %% [markdown]
# ## Data Exploration

# %%
train.info()
print('======================================================')
val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1000000 non-null  object
#  1   vendor_id           1000000 non-null  int64
#  2   pickup_datetime     1000000 non-null  object
#  3   passenger_count     1000000 non-null  int64
#  4   pickup_longitude    1000000 non-null  float64
#  5   pickup_latitude     1000000 non-null  float64
#  6   dropoff_longitude   1000000 non-null  float64
#  7   dropoff_latitude    1000000 non-null  float64
#  8   store_and_fwd_flag  1000000 non-null  object
#  9   trip_duration       1000000 non-null  int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 76.3+ MB
# ======================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229319 entries, 0 to 229318
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  229319 non-null  object
#  1   vendor_id           229319 non-null  int64
#  2   pickup_datetime     229319 non-null  object
#  3   passenger_count     229319 non-null  int64
#  4   pickup_longitude    229319 non-null  float64
#  5   pickup_latitude     229319 non-null  float64
#  6   dropoff_longitude   229319 non-null  float64
#  7   dropoff_latitude    229319 non-null  float64
#  8   store_and_fwd_flag  229319 non-null  object
#  9   trip_duration       229319 non-null  int64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 17.5+ MB

# %%
train.describe()
# Out:
#             vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  1000000.000000   1000000.000000    1000000.000000   1000000.000000
# mean         1.534793         1.665353        -73.973475        40.750947
# std          0.498788         1.315723          0.065404         0.033745
# min          1.000000         0.000000       -121.933342        34.359695
# 25%          1.000000         1.000000        -73.991852        40.737372
# 50%          2.000000         1.000000        -73.981728        40.754131
# 75%          2.000000         2.000000        -73.967346        40.768379
# max          2.000000         7.000000        -61.335529        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count     1000000.000000    1000000.000000   1.000000e+06
# mean          -73.973421         40.751829   9.548850e+02
# std             0.065432          0.035782   3.882070e+03
# min          -121.933304         34.359695   1.000000e+00
# 25%           -73.991341         40.735928   3.970000e+02
# 50%           -73.979767         40.754551   6.620000e+02
# 75%           -73.963036         40.769833   1.074000e+03
# max           -61.335529         43.921028   2.227612e+06

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.head()
# Out:
#           id  vendor_id      pickup_datetime  passenger_count  \
# 0  id2793718          2  2016-06-08 07:36:19                1
# 1  id3485529          2  2016-04-03 12:58:11                1
# 2  id1816614          2  2016-06-05 02:49:13                5
# 3  id1050851          2  2016-05-05 17:18:27                2
# 4  id0140657          1  2016-05-12 17:43:38                4
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.985611        40.735943         -73.980331         40.760468
# 1        -73.978394        40.764351         -73.991623         40.749859
# 2        -73.989059        40.744389         -73.973381         40.748692
# 3        -73.990326        40.731136         -73.991264         40.748917
# 4        -73.789497        40.646675         -73.987137         40.759232
#
#   store_and_fwd_flag  trip_duration
# 0                  N           1040
# 1                  N            827
# 2                  N            614
# 3                  N            867
# 4                  N           4967

# %% [markdown]
# ## EDA

# %% [markdown]
# ### . trip duration (Target)

# %%
plt.figure(figsize = (8,5))
sns.histplot(train['trip_duration'],bins=50 ,kde =True)
plt.title('Distribution of Trip Duration')
plt.xlabel('Trip Duration')
plt.ylabel ('Frequency')
plt.show()

# %% [raw]
# In this dataset, the target variable trip_duration is measured in seconds and is highly skewed — most trips are short, but a few take several hours (or more). To better visualize and model the data, we apply a logarithmic transformation. "log_duration = log(Trip Duration + 1)"

# %%
plt.figure(figsize = (8,5))
sns.histplot(np.log1p (train['trip_duration']),bins=50 ,kde =True)
plt.title('Distribution of Trip Duration')
plt.xlabel('Trip Duration')
plt.ylabel ('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=np.log1p (train['trip_duration']))
plt.title('Boxplot of Trip Duration')
plt.xlabel('Trip Duration')
plt.show()

# %%
#handle outliers using clipping
lower_bound=train['trip_duration'].quantile(0.01)
upper_bound =train ['trip_duration'].quantile(0.99)
train['trip_duration_clipped']= train ['trip_duration'].clip(lower =lower_bound ,upper = upper_bound )

# apply the log transformation
train ['log_trip_duration'] = np.log1p(train['trip_duration_clipped'])

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=np.log1p (train['trip_duration_clipped']))
plt.title('Boxplot of Trip Duration after clipping')
plt.xlabel('Trip Duration')
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot (1,3,1)
sns.histplot(train['trip_duration'], bins=50, kde=True, color='salmon')
plt.title('Original')

plt.subplot (1,3,2)
sns.histplot(train['trip_duration_clipped'], bins=50, kde=True, color='skyblue')
plt.title('After Clipping (1%-99%)')


plt.subplot(1,3,3)
sns.histplot(train['log_trip_duration'], bins=50, kde=True, color='lightgreen')
plt.title('After Clipping + Log Transform')

plt.tight_layout()
plt.show()

# %%
print("Skewness before:", train['trip_duration'].skew())
print("Skewness after Clipping:", train['trip_duration_clipped'].skew())
print("Skewness after Clipping + Log Transform:", train['log_trip_duration'].skew())
# Out:
# Skewness before: 202.55575426164614
# Skewness before: 1.737797911760756
# Skewness after : -0.20374162449589545

# %% [markdown]
# ### . ID

# %%
train.drop(columns='id', axis=1, inplace=True)

# %% [raw]
# removed due to be all unique values and not providing relevant information

# %% [markdown]
# ### . Vendor ID

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=train['vendor_id'])
plt.xlabel('Vendor ID')
plt.ylabel('Number of Trips')
plt.title('Number of Trips per Vendor')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=train['vendor_id'], y=train['trip_duration'])
plt.xlabel('Vendor ID')
plt.ylabel('Average Trip Duration')
plt.title('Average Trip Duration per Vendor')
plt.show()

# %% [raw]
# Vendor 2 has more trip count and longer trip duration

# %% [markdown]
# ### . pickup datetime

# %%
# convert pickup_datetime to datetime
train['pickup_datetime'] = pd.to_datetime(train['pickup_datetime'])

# %%
group = train.groupby(train['pickup_datetime'].dt.date)['trip_duration'].mean()

plt.figure(figsize=(10,5))
plt.plot(group.index, group.values)
plt.xlabel('Month')
plt.ylabel('Trip Duration')
plt.title('Monthly trip duration')
plt.show()

# %%
train['pickup_datetime'].dt.year.unique()
# Out:
# array([2016])

# %% [raw]
# Needs to be converted from Datetime to numerical data

# %%
train['day'] = train['pickup_datetime'].dt.day
train['month'] = train['pickup_datetime'].dt.month
train['day_of_week'] = train['pickup_datetime'].dt.weekday
train['hour'] = train['pickup_datetime'].dt.hour

# %%
features = ['month', 'day', 'day_of_week', 'hour']
plt.figure(figsize=(10, 8))

for i, feature in enumerate(features, 1):
    plt.subplot(2,2,i)
    group = train.groupby(feature)['trip_duration'].mean()
    plt.plot(group.index, group.values, marker='o')
    plt.xlabel(feature)
    plt.ylabel('Trip Duration')
    plt.title(f'{feature} vs trip_duration')
 

plt.tight_layout()
plt.show()

# %% [raw]
# . There is a strong upward trend in the average trip duration from Month 2 to Month 6 (from plot 1)
# . The average trip duration is significantly higher on weekdays than on weekends (from pllot 3)
# . There is a massive peak during the Rush Hour (from plot 4)

# %%
working = [0, 1 , 2 , 3, 4]
rush = [10,11,12,13,14,15, 16, 17]

train['Working_days'] = train['pickup_datetime'].dt.weekday.isin(working).astype(int)
is_working_day = train['pickup_datetime'].dt.weekday.isin(working)
is_rush_time = train['pickup_datetime'].dt.hour.isin(rush)
train['rush_hour'] = (is_working_day & is_rush_time).astype(int)

# %%
features = ['day_of_week', 'Working_days', 'rush_hour']
plt.figure(figsize=(15, 5))

for i, feature in enumerate(features, 1):
    plt.subplot(1, 3, i)
    group = train.groupby(feature)['trip_duration'].count()
    group.plot(kind='bar', ax=plt.gca())
    plt.xlabel(feature)
    plt.ylabel('Number of Trips')
    plt.title(f'{feature} trips')
    plt.xticks(rotation=0)
 

plt.tight_layout()
plt.show()

# %% [raw]
# . The mid-week days not only have longer average durations but also the highest volume of trips (left plot)
# . The majority of the data falls on working days(center plot)
# . The rush_hour period (Bar 1) is where average trip duration is highest but only represents about 25% of the total trip volume (Bar 0). This confirms the feature effectively isolates the minority of trips most impacted by congestion

# %%
group = train.groupby(train['day_of_week'])['rush_hour'].count()

plt.figure(figsize=(10,5))
plt.plot(group.index, group.values, marker='o')
plt.xlabel('Week day')
plt.ylabel('Rush Hour')
plt.title('Day vs Rush Hour')
plt.show()

# %% [markdown]
# ### . passenger_count

# %%
train['passenger_count'].unique()
# Out:
# array([1, 5, 2, 4, 3, 6, 0, 7], dtype=int64)

# %%
group = train.groupby('passenger_count')['trip_duration'].mean()
plt.figure(figsize=(15, 5)) 


plt.subplot(1, 2, 1)
plt.bar(x=train['passenger_count'].value_counts().index, height=train['passenger_count'].value_counts())
plt.xlabel('Passenger Count')
plt.ylabel('Number of Trips')
plt.title('# trips per passenger_count')

plt.subplot(1, 2, 2)
plt.plot(group.index, group.values, marker='o')
plt.xlabel('Passenger Count')
plt.ylabel('Average Trip Duration (seconds)')
plt.title('Average Trip Duration vs Passenger Count')
plt.xticks(group.index)

plt.tight_layout()
plt.show()

# %%
train['passenger_count'].value_counts()
# Out:
# passenger_count
# 1    708628
# 2    143907
# 5     53635
# 3     41012
# 6     33287
# 4     19491
# 0        38
# 7         2
# Name: count, dtype: int64

# %% [raw]
# There are 38 trips with 0 passenger, and 2 trips with 7 passengers and no duration. It does not make sense.

# %%
train = train[~train['passenger_count'].isin([0, 7])]

# %%
group = train.groupby('passenger_count')['trip_duration'].mean()
plt.figure(figsize=(15, 5)) 


plt.subplot(1, 2, 1)
plt.bar(x=train['passenger_count'].value_counts().index, height=train['passenger_count'].value_counts())
plt.xlabel('Passenger Count')
plt.ylabel('Number of Trips')
plt.title('Value Counts of passenger_count')

plt.subplot(1, 2, 2)
plt.plot(group.index, group.values, marker='o')
plt.xlabel('Passenger Count')
plt.ylabel('Average Trip Duration (seconds)')
plt.title('Average Trip Duration vs Passenger Count')
plt.xticks(group.index)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### . latitude and longtitude

# %%
plt.figure(figsize=(10,8))
plt.scatter(
    train['pickup_longitude'], 
    train['pickup_latitude'], 
    s=1, alpha=0.3
)
plt.title('Pickup Location Distribution')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.xlim(-74.05, -73.75)
plt.ylim(40.63, 40.85)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(
    train['dropoff_longitude'], 
    train['dropoff_latitude'], 
    s=1, alpha=1, color='red'
)
plt.title('Dropoff Location Distribution')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.xlim(-74.05, -73.75)
plt.ylim(40.63, 40.85)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=train[train['trip_duration'] < 3600],  # remove extreme outliers
    x='pickup_longitude',
    y='pickup_latitude',
    hue=np.log1p(train[train['trip_duration'] < 3600]['trip_duration']),
    palette='viridis',
    alpha=0.5,
    legend=False
)
plt.title('Pickup Locations Colored by Trip Duration (log scale)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.xlim(-74.05, -73.75)
plt.ylim(40.63, 40.85)
plt.show()

# %% [raw]
# Manhattan Distance

# %%
train['manhattan_distance'] = np.abs(train['pickup_longitude'] - train['dropoff_longitude']) + np.abs(train['pickup_latitude'] - train['dropoff_latitude'])

# %% [raw]
# Haversine Distance

# %%
train['haversine_distance'] = train.apply(
    lambda row: great_circle(
        (row['pickup_latitude'], row['pickup_longitude']),
        (row['dropoff_latitude'], row['dropoff_longitude'])
    ).km, axis=1)

# %% [markdown]
# Distance Ratio

# %%
train['distance_ratio'] = train['manhattan_distance'] / (train['haversine_distance']+ 0.0000000000000000001)

# %% [raw]
# midpoint

# %%
train['midpoint_latitude'] = (train['pickup_latitude'] + train['dropoff_latitude']) / 2
train['midpoint_longitude'] = (train['pickup_longitude'] + train['dropoff_longitude']) / 2

# %% [raw]
# Bearing

# %%
GEO_WGS84 = Geodesic.WGS84

def get_geodesic_bearing(row):
    g = GEO_WGS84.Inverse(row['pickup_latitude'], row['pickup_longitude'],
                          row['dropoff_latitude'], row['dropoff_longitude'])
    return g['azi1'] % 360

train['bearing'] = train.apply(get_geodesic_bearing, axis=1)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.histplot(train['haversine_distance'], bins=50, kde=True, color='blue')
plt.xscale('log')
plt.title('Haversine Distance Distribution')

plt.subplot(1,2,2)
sns.histplot(np.log1p(train['haversine_distance']), bins=50, kde=True, color='orange')
plt.xscale('log')
plt.title('Haversine Distance Distribution logged')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.histplot(train['manhattan_distance'], bins=50, kde=True, color='blue')
plt.xscale('log')
plt.title('Manhattan Distance Distribution')

plt.subplot(1,2,2)
sns.histplot(np.log1p(train['manhattan_distance']), bins=50, kde=True, color='orange')
plt.xscale('log')
plt.title('Manhattan Distance Distribution logged')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='haversine_distance', y='manhattan_distance', data=train, alpha=0.3)
plt.title('Manhattan vs Haversine Distance')
plt.xlabel('Haversine Distance')
plt.ylabel('Manhattan Distance')
plt.show()

# %%
sns.scatterplot(
    x=np.log1p(train['haversine_distance']),
    y= train['log_trip_duration'],
    alpha=0.3
)
plt.title('Log(Trip Duration) vs Log(Haversine Distance)')
plt.xlabel('log(Haversine Distance)')
plt.ylabel('log(Trip Duration)')
plt.show()

# %%
plt.boxplot([train['haversine_distance'],train['manhattan_distance']])
plt.xlabel('Distances')
plt.title('Detect Distances Outliers')
plt.show()

# %%
train = train[train['haversine_distance'] < 100]

# %%
plt.boxplot([train['haversine_distance'],train['manhattan_distance']])
plt.xlabel('Distances')
plt.title('Detect Distances Outliers')
plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999945 entries, 0 to 999999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   vendor_id              999945 non-null  int64
#  1   pickup_datetime        999945 non-null  datetime64[ns]
#  2   passenger_count        999945 non-null  int64
#  3   pickup_longitude       999945 non-null  float64
#  4   pickup_latitude        999945 non-null  float64
#  5   dropoff_longitude      999945 non-null  float64
#  6   dropoff_latitude       999945 non-null  float64
#  7   store_and_fwd_flag     999945 non-null  object
#  8   trip_duration          999945 non-null  int64
#  9   trip_duration_clipped  999945 non-null  float64
#  10  log_trip_duration      999945 non-null  float64
#  11  day                    999945 non-null  int32
#  12  month                  999945 non-null  int32
#  13  day_of_week            999945 non-null  int32
#  14  hour                   999945 non-null  int32
#  15  Working_days           999945 non-null  int32
#  16  rush_hour              999945 non-null  int32
#  17  manhattan_distance     999945 non-null  float64
#  18  haversine_distance     999945 non-null  float64
#  19  distance_ratio         999945 non-null  float64
#  20  midpoint_latitude      999945 non-null  float64
#  21  midpoint_longitude     999945 non-null  float64
#  22  bearing                999945 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int32(6), int64(3), object(1)
# memory usage: 160.2+ MB

# %%
train_filtered = train.drop(['trip_duration', 'trip_duration_clipped'], axis=1)
col = train_filtered.pop('log_trip_duration')
train_filtered['log_trip_duration'] = col

# %%
num_features = train_filtered.select_dtypes(include='number').columns
corr = train_filtered[num_features].corr()

plt.figure(figsize=(20,15))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation between Distance and Trip Duration")

plt.show()
